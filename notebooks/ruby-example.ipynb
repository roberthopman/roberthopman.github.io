# %% [markdown]
# # Ruby Output Types
#
# Demonstrating stdout, stderr, and return values in Jupyter.

# %% [markdown]
# ### stdout
#
# `puts` writes to stdout:

# %%
puts "This is stdout"
# Out:
# This is stdout

# %% [markdown]
# ### stderr
#
# Two ways to write to stderr:

# %%
warn "Using warn"
# Out:
# Using warn

# %%
$stderr.puts "Using $stderr.puts"
# Out:
# Using $stderr.puts

# %% [markdown]
# ### Return value
#
# The last expression's value shows with Out label:

# %%
"This is a return value"
# Out:
# "This is a return value"

# %% [markdown]
# ### All three together
#
# Output order: stdout, stderr, then return value:

# %%
puts "1. stdout via puts"
warn "2. stderr via warn"
$stderr.puts "3. stderr via $stderr.puts"
"4. return value"
# Out:
# 1. stdout via puts
# 2. stderr via warn
# 3. stderr via $stderr.puts
# "4. return value"
